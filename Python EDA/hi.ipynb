# %%
print("hello world")
# Out:
# Running cells with 'project (Python 3.11.16)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n project ipykernel --update-deps --force-reinstall'

# %%
3+5
