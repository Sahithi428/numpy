# %%
2 + 3 + 9
# Out:
# 14

# %%
99 - 73
# Out:
# 26

# %%
23.54* - 1432
# Out:
# -33709.28

# %%
100/7
# Out:
# 14.285714285714286

# %%
100//7
# Out:
# 14

# %%
100%7
# Out:
# 2

# %%
5**3
# Out:
# 125

# %%
((2+5)*(17-3)/(4**3))
# Out:
# 1.53125

# %%
500*(.2*1100)
# Out:
# 110000.0

# %%
cost_of_rice_bag=1100
profit_margin = .2
number_of_bags = 500

# %%
profit_margin
# Out:
# 0.2

# %%
profit_per_bag = cost_of_rice_bag * profit_margin

# %%
profit_per_bag
# Out:
# 220.0

# %%
total_profit = number_of_bags * profit_per_bag

# %%
total_profit
# Out:
# 110000.0

# %%
print("The grocery store makes a total profit of Rs.", total_profit)
# Out:
# The grocery store makes a total profit of Rs. 110000.0

# %%
cost_of_rice_bag = 1100
profit_margin = .2
number_of_bags = 500
profit_per_bag = cost_of_rice_bag * profit_margin
total_profit = number_of_bags * profit_per_bag
print("The grocery store makes a total profit of Rs", total_profit)
# Out:
# The grocery store makes a total profit of Rs 110000.0

# %%
my_income=100
tax_rate = 0.1
my_taxes=my_income*tax_rate

# %%
flyingtheplanecost=5000
peoplesignedup=29
companycharges=200
profitforcompany=29*200
totalprofit=profitbycompany*flyingtheplanecost
print("The total profit of Rs", totalprofit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-03ebe012e3a6> in <module>
#       3 companycharges=200
#       4 profitforcompany=29*200
# ----> 5 totalprofit=profitbycompany*flyingtheplanecost
#       6 print("The total profit of Rs", totalprofit)
#
# NameError: name 'profitbycompany' is not defined
